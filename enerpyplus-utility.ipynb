# %% [markdown]
# <a href="https://colab.research.google.com/github.com/janithcyapa/energy-plus-utility/blob/main/enerpyplus-utility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
